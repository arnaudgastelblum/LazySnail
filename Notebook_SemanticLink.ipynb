# %% [markdown]
# # Semantic Link

# %% [markdown]
# ## Setup: Installing and Importing Required Libraries

# %%
# %pip install semantic-link
# %load_ext sempy
import sempy.fabric as fabric
# Out:
# StatementMeta(, cd358454-212c-46f2-a9d3-add66d5e5e7f, 8, Finished, Available, Finished)
# Collecting semantic-link
#   Downloading semantic_link-0.9.3-py3-none-any.whl (9.9 kB)
# Collecting semantic-link-functions-phonenumbers==0.9.3
#   Downloading semantic_link_functions_phonenumbers-0.9.3-py3-none-any.whl (4.3 kB)
# Collecting semantic-link-functions-meteostat==0.9.3
#   Downloading semantic_link_functions_meteostat-0.9.3-py3-none-any.whl (4.5 kB)
# Collecting semantic-link-functions-validators==0.9.3
#   Downloading semantic_link_functions_validators-0.9.3-py3-none-any.whl (4.7 kB)
# Collecting semantic-link-functions-geopandas==0.9.3
#   Downloading semantic_link_functions_geopandas-0.9.3-py3-none-any.whl (4.0 kB)
# Collecting semantic-link-functions-holidays==0.9.3
#   Downloading semantic_link_functions_holidays-0.9.3-py3-none-any.whl (4.2 kB)
# Collecting semantic-link-sempy==0.9.3
#   Downloading semantic_link_sempy-0.9.3-py3-none-any.whl (3.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.2/3.2 MB 45.0 MB/s eta 0:00:0000:0100:01
# Collecting mapclassify
#   Downloading mapclassify-2.8.1-py3-none-any.whl (59 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 59.1/59.1 kB 31.1 MB/s eta 0:00:00
# Collecting folium
#   Downloading folium-0.19.5-py2.py3-none-any.whl (110 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 110.9/110.9 kB 49.9 MB/s eta 0:00:00
# Collecting geopandas
#   Downloading geopandas-1.0.1-py3-none-any.whl (323 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 323.6/323.6 kB 96.9 MB/s eta 0:00:00
# Collecting holidays
#   Downloading holidays-0.68-py3-none-any.whl (824 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 824.7/824.7 kB 129.9 MB/s eta 0:00:00
# Collecting meteostat
#   Downloading meteostat-1.6.8-py3-none-any.whl (31 kB)
# Collecting phonenumbers
#   Downloading phonenumbers-9.0.0-py2.py3-none-any.whl (2.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.6/2.6 MB 171.5 MB/s eta 0:00:00
# Collecting validators
#   Downloading validators-0.34.0-py3-none-any.whl (43 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.5/43.5 kB 18.2 MB/s eta 0:00:00
# Collecting setuptools>=68.2.2
#   Downloading setuptools-76.0.0-py3-none-any.whl (1.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 168.9 MB/s eta 0:00:00
# Collecting pyarrow>=12.0.1
#   Downloading pyarrow-19.0.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (42.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.2/42.2 MB 102.8 MB/s eta 0:00:0000:0100:01
# Collecting pythonnet>=3.0.1
#   Downloading pythonnet-3.0.5-py3-none-any.whl (297 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 297.5/297.5 kB 101.1 MB/s eta 0:00:00
# Collecting rich>=13.3.5
#   Downloading rich-13.9.4-py3-none-any.whl (242 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 242.4/242.4 kB 92.9 MB/s eta 0:00:00
# Collecting scikit-learn>=1.2.2
#   Downloading scikit_learn-1.6.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (13.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.5/13.5 MB 141.2 MB/s eta 0:00:0000:0100:01
# Collecting clr-loader>=0.2.5
#   Downloading clr_loader-0.2.7.post0-py3-none-any.whl (50 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.6/50.6 kB 20.3 MB/s eta 0:00:00
# Requirement already satisfied: tqdm>=4.65.0 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.10/site-packages (from semantic-link-sempy==0.9.3->semantic-link) (4.65.0)
# Requirement already satisfied: graphviz>=0.20.1 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.10/site-packages (from semantic-link-sempy==0.9.3->semantic-link) (0.20.1)
# Collecting cffi>=1.17
#   Downloading cffi-1.17.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (446 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 446.2/446.2 kB 113.9 MB/s eta 0:00:00
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.10/site-packages (from rich>=13.3.5->semantic-link-sempy==0.9.3->semantic-link) (2.14.0)
# Collecting markdown-it-py>=2.2.0
#   Downloading markdown_it_py-3.0.0-py3-none-any.whl (87 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 87.5/87.5 kB 38.7 MB/s eta 0:00:00
# Requirement already satisfied: typing-extensions<5.0,>=4.0.0 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.10/site-packages (from rich>=13.3.5->semantic-link-sempy==0.9.3->semantic-link) (4.5.0)
# Requirement already satisfied: joblib>=1.2.0 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.10/site-packages (from scikit-learn>=1.2.2->semantic-link-sempy==0.9.3->semantic-link) (1.2.0)
# Requirement already satisfied: numpy>=1.19.5 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.10/site-packages (from scikit-learn>=1.2.2->semantic-link-sempy==0.9.3->semantic-link) (1.23.5)
# Requirement already satisfied: scipy>=1.6.0 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.10/site-packages (from scikit-learn>=1.2.2->semantic-link-sempy==0.9.3->semantic-link) (1.10.1)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.10/site-packages (from scikit-learn>=1.2.2->semantic-link-sempy==0.9.3->semantic-link) (3.1.0)
# Requirement already satisfied: jinja2>=2.9 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.10/site-packages (from folium->semantic-link-functions-geopandas==0.9.3->semantic-link) (3.1.2)
# Collecting branca>=0.6.0
#   Downloading branca-0.8.1-py3-none-any.whl (26 kB)
# Requirement already satisfied: requests in /home/trusted-service-user/cluster-env/trident_env/lib/python3.10/site-packages (from folium->semantic-link-functions-geopandas==0.9.3->semantic-link) (2.28.2)
# Collecting xyzservices
#   Downloading xyzservices-2025.1.0-py3-none-any.whl (88 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 88.4/88.4 kB 42.6 MB/s eta 0:00:00
# Requirement already satisfied: packaging in /home/trusted-service-user/cluster-env/trident_env/lib/python3.10/site-packages (from geopandas->semantic-link-functions-geopandas==0.9.3->semantic-link) (22.0)
# Collecting shapely>=2.0.0
#   Downloading shapely-2.0.7-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.5/2.5 MB 162.2 MB/s eta 0:00:00
# Collecting pyproj>=3.3.0
#   Downloading pyproj-3.7.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (9.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.3/9.3 MB 169.1 MB/s eta 0:00:0000:01
# Collecting pyogrio>=0.7.2
#   Downloading pyogrio-0.10.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (23.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.7/23.7 MB 133.9 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: pandas>=1.4.0 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.10/site-packages (from geopandas->semantic-link-functions-geopandas==0.9.3->semantic-link) (1.5.3)
# Requirement already satisfied: python-dateutil in /home/trusted-service-user/cluster-env/trident_env/lib/python3.10/site-packages (from holidays->semantic-link-functions-holidays==0.9.3->semantic-link) (2.8.2)
# Collecting networkx>=2.7
#   Downloading networkx-3.4.2-py3-none-any.whl (1.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 172.9 MB/s eta 0:00:00
# Requirement already satisfied: pytz in /home/trusted-service-user/cluster-env/trident_env/lib/python3.10/site-packages (from meteostat->semantic-link-functions-meteostat==0.9.3->semantic-link) (2022.7.1)
# Requirement already satisfied: pycparser in /home/trusted-service-user/cluster-env/trident_env/lib/python3.10/site-packages (from cffi>=1.17->clr-loader>=0.2.5->semantic-link-sempy==0.9.3->semantic-link) (2.21)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.10/site-packages (from jinja2>=2.9->folium->semantic-link-functions-geopandas==0.9.3->semantic-link) (2.1.2)
# Collecting mdurl~=0.1
#   Downloading mdurl-0.1.2-py3-none-any.whl (10.0 kB)
# Requirement already satisfied: certifi in /home/trusted-service-user/cluster-env/trident_env/lib/python3.10/site-packages (from pyogrio>=0.7.2->geopandas->semantic-link-functions-geopandas==0.9.3->semantic-link) (2022.12.7)
# Requirement already satisfied: six>=1.5 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.10/site-packages (from python-dateutil->holidays->semantic-link-functions-holidays==0.9.3->semantic-link) (1.16.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.10/site-packages (from requests->folium->semantic-link-functions-geopandas==0.9.3->semantic-link) (1.26.14)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.10/site-packages (from requests->folium->semantic-link-functions-geopandas==0.9.3->semantic-link) (2.1.1)
# Requirement already satisfied: idna<4,>=2.5 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.10/site-packages (from requests->folium->semantic-link-functions-geopandas==0.9.3->semantic-link) (3.4)
# Installing collected packages: phonenumbers, xyzservices, validators, shapely, setuptools, pyproj, pyogrio, pyarrow, networkx, mdurl, cffi, scikit-learn, markdown-it-py, holidays, clr-loader, branca, rich, pythonnet, meteostat, mapclassify, geopandas, folium, semantic-link-sempy, semantic-link-functions-validators, semantic-link-functions-phonenumbers, semantic-link-functions-meteostat, semantic-link-functions-holidays, semantic-link-functions-geopandas, semantic-link
#   Attempting uninstall: setuptools
#     Found existing installation: setuptools 67.6.1
#     Not uninstalling setuptools at /home/trusted-service-user/cluster-env/trident_env/lib/python3.10/site-packages, outside environment /nfs4/pyenv-c7547045-5537-4d0d-b60f-677490d5340e
#     Can't uninstall 'setuptools'. No files were found to uninstall.
#   Attempting uninstall: pyarrow
#     Found existing installation: pyarrow 11.0.0
#     Not uninstalling pyarrow at /home/trusted-service-user/cluster-env/trident_env/lib/python3.10/site-packages, outside environment /nfs4/pyenv-c7547045-5537-4d0d-b60f-677490d5340e
#     Can't uninstall 'pyarrow'. No files were found to uninstall.
#   Attempting uninstall: cffi
#     Found existing installation: cffi 1.15.1
#     Not uninstalling cffi at /home/trusted-service-user/cluster-env/trident_env/lib/python3.10/site-packages, outside environment /nfs4/pyenv-c7547045-5537-4d0d-b60f-677490d5340e
#     Can't uninstall 'cffi'. No files were found to uninstall.
#   Attempting uninstall: scikit-learn
#     Found existing installation: scikit-learn 1.2.0
#     Not uninstalling scikit-learn at /home/trusted-service-user/cluster-env/trident_env/lib/python3.10/site-packages, outside environment /nfs4/pyenv-c7547045-5537-4d0d-b60f-677490d5340e
#     Can't uninstall 'scikit-learn'. No files were found to uninstall.
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# lime 0.2.0.1 requires scikit-image>=0.12, which is not installed.
# azureml-core 1.49.0 requires packaging<22.0,>=20.0, but you have packaging 22.0 which is incompatible.
# azureml-core 1.49.0 requires paramiko<3.0.0,>=2.0.8, but you have paramiko 3.5.0 which is incompatible.
# Successfully installed branca-0.8.1 cffi-1.17.1 clr-loader-0.2.7.post0 folium-0.19.5 geopandas-1.0.1 holidays-0.68 mapclassify-2.8.1 markdown-it-py-3.0.0 mdurl-0.1.2 meteostat-1.6.8 networkx-3.4.2 phonenumbers-9.0.0 pyarrow-19.0.1 pyogrio-0.10.0 pyproj-3.7.1 pythonnet-3.0.5 rich-13.9.4 scikit-learn-1.6.1 semantic-link-0.9.3 semantic-link-functions-geopandas-0.9.3 semantic-link-functions-holidays-0.9.3 semantic-link-functions-meteostat-0.9.3 semantic-link-functions-phonenumbers-0.9.3 semantic-link-functions-validators-0.9.3 semantic-link-sempy-0.9.3 setuptools-76.0.0 shapely-2.0.7 validators-0.34.0 xyzservices-2025.1.0
#
# [notice] A new release of pip is available: 23.0 -> 25.0.1
# [notice] To update, run: /nfs4/pyenv-c7547045-5537-4d0d-b60f-677490d5340e/bin/python -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.
# Warning: PySpark kernel has been restarted to use updated packages.

# %% [markdown]
# ## Exploring Power BI Semantic Models with Python in Microsoft Fabric

# %% [markdown]
# ### List tables from a Power BI Semantic model
#
# The `list_tables()` function in the Semantic Link extension retrieves the list of available tables in a Microsoft Fabric semantic model. It helps explore the model by displaying the names of accessible tables.
#
# https://learn.microsoft.com/en-us/python/api/semantic-link-sempy/sempy.fabric?view=semantic-link-python#sempy-fabric-list-tables

# %%
fabric.list_tables("LazyDAX")
# Out:
# StatementMeta(, cd358454-212c-46f2-a9d3-add66d5e5e7f, 10, Finished, Available, Finished)
#                Name                                        Description  \
# 0          Customer  You and Me, people who wants to eat fresh frui...
# 1           Product  Only Fruits and Vegetables because a healthy l...
# 2       SalesPerson  Persons with a black suit who wants you to spe...
# 3             Sales  Fact Table contains Sales information\nGrain (...
# 4          Calendar
# 5    Measures Group  Empty table, created to group all measures in ...
# 6        Navigation
# 7               DAX
# 8  Fields_Parameter
# 9         Parameter
#
#    Hidden Data Category              Type
# 0   False                           Table
# 1   False                           Table
# 2   False                           Table
# 3   False                           Table
# 4   False          Time             Table
# 5   False                           Table
# 6    True                           Table
# 7    True                           Table
# 8   False                Calculated Table
# 9   False                Calculated Table

# %% [markdown]
# ### List Measures from a Power BI Semantic model
#
# The `list_measures()` function retrieves all measures from a dataset in a Microsoft Fabric semantic model. It provides an overview of the available calculated metrics.
#
# https://learn.microsoft.com/en-us/python/api/semantic-link-sempy/sempy.fabric?view=semantic-link-python#sempy-fabric-list-measures

# %%
fabric.list_measures("LazyDAX")
# Out:
# StatementMeta(, cd358454-212c-46f2-a9d3-add66d5e5e7f, 11, Finished, Available, Finished)
#          Table Name               Measure Name  \
# 0    Measures Group            SUM TotalAmount
# 1    Measures Group               SUM Discount
# 2    Measures Group               SUM Quantity
# 3    Measures Group              SUM UnitPrice
# 4    Measures Group  DISTINCTCOUNT Transaction
# ..              ...                        ...
# 491  Measures Group                        TAN
# 492  Measures Group                       TANH
# 493  Measures Group                      TRUNC
# 494  Measures Group             EvaluateAndLog
# 495  Measures Group             INDEX Number 4
#
#                                     Measure Expression Measure Data Type  \
# 0                              SUM(Sales[TotalAmount])            Double
# 1                                 SUM(Sales[Discount])            Double
# 2                                 SUM(Sales[Quantity])             Int64
# 3                                SUM(Sales[UnitPrice])            Double
# 4                  DISTINCTCOUNT(Sales[InvoiceNumber])             Int64
# ..                                                 ...               ...
# 491  -- Returns the tangent of the given angle.\nTA...            Double
# 492  -- Returns the hyperbolic tangent of a number....            Double
# 493  -- Truncates a number to an integer by removin...             Int64
# 494  EvaluateAndLog(SUM(Sales[Quantity])) * Evaluat...            Double
# 495  \n-- https://learn.microsoft.com/en-us/dax/ind...            String
#
#      Measure Hidden       Measure Display Folder  \
# 0             False    Aggregation functions\Sum
# 1             False    Aggregation functions\Sum
# 2             False    Aggregation functions\Sum
# 3             False    Aggregation functions\Sum
# 4             False  Aggregation functions\Count
# ..              ...                          ...
# 491           False      Math and trig functions
# 492           False      Math and trig functions
# 493           False      Math and trig functions
# 494           False                         Misc
# 495           False             Filter functions
#
#                                    Measure Description  \
# 0                           SUM ( Sales[TotalAmount] )
# 1                              SUM ( Sales[Discount] )
# 2                              SUM ( Sales[Quantity] )
# 3                             SUM ( Sales[UnitPrice] )
# 4               DISTINCTCOUNT ( Sales[InvoiceNumber] )
# ..                                                 ...
# 491  -- Returns the tangent of the given angle.\nTA...
# 492  -- Returns the hyperbolic tangent of a number....
# 493  -- Truncates a number to an integer by removin...
# 494
# 495
#
#                                          Format String Data Category  \
# 0                 #,0.00\ "€";-#,0.00\ "€";#,0.00\ "€"
# 1    "€"#,0.###############;("€"#,0.###############...
# 2                                                    0
# 3    "€"#,0.###############;("€"#,0.###############...
# 4                                                    0
# ..                                                 ...           ...
# 491
# 492
# 493
# 494
# 495
#
#     Detail Rows Definition Format String Definition
# 0                     None                     None
# 1                     None                     None
# 2                     None                     None
# 3                     None                     None
# 4                     None                     None
# ..                     ...                      ...
# 491                   None                     None
# 492                   None                     None
# 493                   None                     None
# 494                   None                     None
# 495                   None                     None
#
# [496 rows x 11 columns]

# %% [markdown]
# ## Querying DAX
# This section demonstrates how to run a DAX query in a Python notebook within Microsoft Fabric using the Semantic Link (sempy) extension.

# %% [markdown]
# ### Load the sempy extension

# %%
# %load_ext sempy
# Out:
# StatementMeta(, cd358454-212c-46f2-a9d3-add66d5e5e7f, 12, Finished, Available, Finished)
# The sempy extension is already loaded. To reload it, use:
#   %reload_ext sempy

# %% [markdown]
# ### Execute a DAX Query
#
# The `%%dax` cell magic runs a DAX query directly within the notebook`<br>
# "LazyDAX" refers to the semantic model being queried.

# %%
# %%dax "LazyDAX"
# EVALUATE
# SUMMARIZECOLUMNS(
#     'Customer'[Country]
#     ,"test", SUM(Sales[TotalAmount])
# )
# Out:
# StatementMeta(, cd358454-212c-46f2-a9d3-add66d5e5e7f, 13, Finished, Available, Finished)
#   Customer[Country]   [test]
# 0           Belgium  1311.68
# 1            France  1147.01
# 2         Nederland  1269.84

# %% [markdown]
# ## Querying a Power BI Semantic Model with SQL
# This section demonstrates how to use SQL queries to retrieve data from a Power BI Semantic Model in Microsoft Fabric.

# %% [markdown]
# ### Configure Spark to Access the Semantic Model
# The following command configures Spark to use the Power BI Spark native connector for Spark SQL
#
# More information: https://learn.microsoft.com/en-us/fabric/data-science/semantic-link-power-bi?tabs=sql

# %%
spark.conf.set("spark.sql.catalog.pbi", "com.microsoft.azure.synapse.ml.powerbi.PowerBICatalog")
# Out:
# StatementMeta(, cd358454-212c-46f2-a9d3-add66d5e5e7f, 14, Finished, Available, Finished)

# %% [markdown]
# ### Retrieve Data from a Table
# The `%sq` cell magic allows executing SQL queries within the notebook.<br>
# This query retrieves all columns from the Customer table inside the LazyDAX semantic model.

# %%
# %%sql
# SELECT *
# FROM pbi.`LazyDAX`.Customer
# Out:
# StatementMeta(, cd358454-212c-46f2-a9d3-add66d5e5e7f, 15, Finished, Available, Finished)
# <Spark SQL result set with 12 rows and 19 fields>

# %% [markdown]
# ### Aggregating Data with SQL
# This query achieves the same result as the previous DAX expression, but using SQL on the same Power BI Semantic Model.<br>
# Here, we not only aggregate data but also join tables to combine relevant information:

# %%
# %%sql
# SELECT
#      Customer.Country
#     ,SUM(Sales.TotalAmount)
# FROM       pbi.`LazyDAX`.Sales
# INNER JOIN pbi.`LazyDAX`.Customer ON Customer.PK_Customer = Sales.FK_Customer
# GROUP BY Customer.Country
# Out:
# StatementMeta(, cd358454-212c-46f2-a9d3-add66d5e5e7f, 16, Finished, Available, Finished)
# <Spark SQL result set with 3 rows and 2 fields>

# %% [markdown]
# # Visualizing the Data Model
#
# This section demonstrates how to extract and visualize relationships within a Power BI Semantic Model using the Semantic Link extension in Microsoft Fabric.<br>
# `sempy.fabric` provides access to the semantic model.<br>
# `plot_relationship_metadat` is used to generate the relationship diagram.

# %%
import sempy.fabric as fabric
import pyspark.sql.functions as F

from sempy.relationships import plot_relationship_metadata
from sempy.relationships import find_relationships

relationships = fabric.list_relationships("LazyDAX")
plot_relationship_metadata(relationships)
# Out:
# StatementMeta(, cd358454-212c-46f2-a9d3-add66d5e5e7f, 17, Finished, Available, Finished)

# %% [markdown]
# # DAX Semantic Model informations

# %% [markdown]
# ## Exploring Active Relationships in a Power BI Semantic Model
# This section demonstrates how to retrieve active relationships from a Power BI Semantic Model using a DAX query.
#
# `$System.DISCOVER_CALC_DEPENDENCY` is a system table that provides metadata about dependencies within the semantic model.<br>
# The filter on `OBJECT_TYPE = 'ACTIVE_RELATIONSHIP'` ensures that only active relationships are retrieved.

# %%
# %%dax "LazyDAX"
#
# SELECT * FROM $System.DISCOVER_CALC_DEPENDENCY WHERE OBJECT_TYPE = 'ACTIVE_RELATIONSHIP'
# Out:
# StatementMeta(, cd358454-212c-46f2-a9d3-add66d5e5e7f, 18, Finished, Available, Finished)
#    DATABASE_NAME          OBJECT_TYPE     TABLE  \
# 0        LazyDAX  ACTIVE_RELATIONSHIP  Customer
# 1        LazyDAX  ACTIVE_RELATIONSHIP  Customer
# 2        LazyDAX  ACTIVE_RELATIONSHIP  Customer
# 3        LazyDAX  ACTIVE_RELATIONSHIP  Customer
# 4        LazyDAX  ACTIVE_RELATIONSHIP     Sales
# 5        LazyDAX  ACTIVE_RELATIONSHIP     Sales
# 6        LazyDAX  ACTIVE_RELATIONSHIP     Sales
# 7        LazyDAX  ACTIVE_RELATIONSHIP     Sales
# 8        LazyDAX  ACTIVE_RELATIONSHIP     Sales
# 9        LazyDAX  ACTIVE_RELATIONSHIP     Sales
# 10       LazyDAX  ACTIVE_RELATIONSHIP     Sales
# 11       LazyDAX  ACTIVE_RELATIONSHIP     Sales
#
#                                   OBJECT EXPRESSION REFERENCED_OBJECT_TYPE  \
# 0   8f92ca78-2ec7-48fd-83a8-f4926aa422af       <NA>                 COLUMN
# 1   8f92ca78-2ec7-48fd-83a8-f4926aa422af       <NA>            CALC_COLUMN
# 2   860e0bd8-55b4-4647-86f5-a103a6df31cb       <NA>                 COLUMN
# 3   860e0bd8-55b4-4647-86f5-a103a6df31cb       <NA>            CALC_COLUMN
# 4   ed4c9cd4-1d31-413b-a324-21a61ee6899c       <NA>                 COLUMN
# 5   ed4c9cd4-1d31-413b-a324-21a61ee6899c       <NA>                 COLUMN
# 6   13cd194c-f7f7-4ea9-9793-60a2bd54aab2       <NA>                 COLUMN
# 7   13cd194c-f7f7-4ea9-9793-60a2bd54aab2       <NA>                 COLUMN
# 8   d581473a-317e-4d23-9fba-fdf59723aa4f       <NA>                 COLUMN
# 9   d581473a-317e-4d23-9fba-fdf59723aa4f       <NA>                 COLUMN
# 10  88c471e9-42b5-461c-8c8f-97b6b65dcde5       <NA>                 COLUMN
# 11  88c471e9-42b5-461c-8c8f-97b6b65dcde5       <NA>                 COLUMN
#
#                                      REFERENCED_TABLE REFERENCED_OBJECT  \
# 0                                            Customer         Birthdate
# 1   LocalDateTable_2bb3bf9a-4588-4b0b-9d55-0d93e7c...              Date
# 2                                            Customer      RegisterDate
# 3   LocalDateTable_84756282-14e7-4ad1-8bba-1ad039c...              Date
# 4                                            Customer       PK_Customer
# 5                                               Sales       FK_Customer
# 6                                             Product        PK_Product
# 7                                               Sales        FK_Product
# 8                                         SalesPerson    PK_SalesPerson
# 9                                               Sales    FK_SalesPerson
# 10                                              Sales      FK_SalesDate
# 11                                           Calendar           PK_Date
#
#    REFERENCED_EXPRESSION QUERY
# 0                   <NA>  <NA>
# 1                   <NA>  <NA>
# 2                   <NA>  <NA>
# 3                   <NA>  <NA>
# 4                   <NA>  <NA>
# 5                   <NA>  <NA>
# 6                   <NA>  <NA>
# 7                   <NA>  <NA>
# 8                   <NA>  <NA>
# 9                   <NA>  <NA>
# 10                  <NA>  <NA>
# 11                  <NA>  <NA>

# %% [markdown]
# ## Column Impact: Who Uses This Column?
# This section demonstrates how to analyze the impact of a specific column in a Power BI Semantic Model using a DAX query.<br>
# `INFO.CALCDEPENDENCY()` returns metadata about objects that reference other elements in the model.<br>
# The `FILTER` function narrows down the results to only those referencing the "Year" column in the "Calendar" table.

# %%
# %%dax "LazyDAX"
#
# EVALUATE
#     FILTER(
#          INFO.CALCDEPENDENCY()
#         ,
#                [REFERENCED_TABLE]  = "Calendar"
#             && [REFERENCED_OBJECT] = "Year"
#     )
# Out:
# StatementMeta(, cd358454-212c-46f2-a9d3-add66d5e5e7f, 19, Finished, Available, Finished)
#    [DATABASE_NAME] [OBJECT_TYPE]         [TABLE]  \
# 0          LazyDAX       MEASURE  Measures Group
# 1          LazyDAX       MEASURE  Measures Group
# 2          LazyDAX     HIERARCHY        Calendar
# 3          LazyDAX       MEASURE  Measures Group
# 4          LazyDAX       MEASURE  Measures Group
# 5          LazyDAX       MEASURE  Measures Group
# 6          LazyDAX       MEASURE  Measures Group
# 7          LazyDAX       MEASURE  Measures Group
# 8          LazyDAX       MEASURE  Measures Group
# 9          LazyDAX       MEASURE  Measures Group
# 10         LazyDAX       MEASURE  Measures Group
# 11         LazyDAX       MEASURE  Measures Group
#
#                               [OBJECT]  \
# 0                  Churn Old Customers
# 1                  Churn New Customers
# 2                       Date Hierarchy
# 3        % Evolution / Total This Year
# 4                           Amount Y-1
# 5                    Amount Y-1 Filter
# 6                  Amount Y-1 Filter 2
# 7                     Amount Y-1 Fruit
# 8                     CALCULATE FILTER
# 9                   CALCULATE FILTER 2
# 10  CALCULATE FILTER (Many conditions)
# 11                         DumpFilters
#
#                                          [EXPRESSION]  \
# 0
#     VAR CurrentYear = MAX('Calendar'[Year])
#  ...
# 1
#     VAR CurrentYear = MAX('Calendar'[Year])
#  ...
# 2                                                <NA>
# 3
#     VAR CurrentYear = MAX('Calendar'[Year])
#  ...
# 4
#     VAR CurrentYear = MAX('Calendar'[Year])
#  ...
# 5
#     VAR CurrentYear = MAX('Calendar'[Year])
#  ...
# 6
#     VAR CurrentYear = MAX('Calendar'[Year])
#  ...
# 7
#     VAR CurrentYear = MAX('Calendar'[Year])
#  ...
# 8
#     VAR CurrentYear = MAX('Calendar'[Year])
#  ...
# 9
#     VAR CurrentYear = MAX('Calendar'[Year])
#  ...
# 10
#     VAR CurrentYear = MAX('Calendar'[Year])
#  ...
# 11
# -- This measure allow you to list all the fil...
#
#    [REFERENCED_OBJECT_TYPE] [REFERENCED_TABLE] [REFERENCED_OBJECT]  \
# 0                    COLUMN           Calendar                Year
# 1                    COLUMN           Calendar                Year
# 2       ATTRIBUTE_HIERARCHY           Calendar                Year
# 3                    COLUMN           Calendar                Year
# 4                    COLUMN           Calendar                Year
# 5                    COLUMN           Calendar                Year
# 6                    COLUMN           Calendar                Year
# 7                    COLUMN           Calendar                Year
# 8                    COLUMN           Calendar                Year
# 9                    COLUMN           Calendar                Year
# 10                   COLUMN           Calendar                Year
# 11                   COLUMN           Calendar                Year
#
#    [REFERENCED_EXPRESSION] [QUERY]
# 0                     <NA>    <NA>
# 1                     <NA>    <NA>
# 2                     <NA>    <NA>
# 3                     <NA>    <NA>
# 4                     <NA>    <NA>
# 5                     <NA>    <NA>
# 6                     <NA>    <NA>
# 7                     <NA>    <NA>
# 8                     <NA>    <NA>
# 9                     <NA>    <NA>
# 10                    <NA>    <NA>
# 11                    <NA>    <NA>

# %% [markdown]
# # Fabric / Power BI Capacities
# https://learn.microsoft.com/en-us/python/api/semantic-link-sempy/sempy.fabric?view=semantic-link-python#sempy-fabric-list-capacities

# %%
fabric.list_capacities()
# Out:
# StatementMeta(, cd358454-212c-46f2-a9d3-add66d5e5e7f, 21, Finished, Available, Finished)
#                                      Id  \
# 0  b45eeab1-2788-4d7f-a105-e49082017fec
# 1  fc3a303d-1acc-43d8-84b8-2a0b7a81a6d4
#
#                                       Display Name  Sku        Region   State
# 0  Trial-argastel-dieteren-be-06-09-2023-11-21-UTC  FT1  North Europe  Active
# 1                      Premium Per User - Reserved  PP3  North Europe  Active

# %% [markdown]
# ## Exploring M Code in a Power BI Semantic Model
#
# This section demonstrates how to list and inspect M (Power Query) expressions used in a Power BI Semantic Model within Microsoft Fabric.

# %%
fabric.list_expressions(dataset="LazyDAX")
# Out:
# StatementMeta(, cd358454-212c-46f2-a9d3-add66d5e5e7f, 22, Finished, Available, Finished)
#                            Name Description  \
# 0       CreateCalendarDimension
# 1      Description_Introduction
# 2             Description_Other
# 3                Description_UI
# 4             Description_Basic
# 5  Description_TimeIntelligence
#
#                                           Expression Kind M Attributes  \
# 0  let CreateDateTable = (StartDate as date, EndD...    M
# 1  let\n    Source = Table.FromRows(Json.Document...    M
# 2  let\n    Source = Table.FromRows(Json.Document...    M
# 3  let\n    Source = Table.FromRows(Json.Document...    M
# 4  let\n    Source = Table.FromRows(Json.Document...    M
# 5  let\n    Source = Table.FromRows(Json.Document...    M
#
#         Modified Time
# 0 2022-06-16 10:46:42
# 1 2022-06-16 10:46:42
# 2 2022-06-16 10:46:42
# 3 2022-06-16 10:46:42
# 4 2022-06-16 10:46:42
# 5 2022-06-16 10:46:42

# %% [markdown]
# ## List All existing workspaces
#
# https://learn.microsoft.com/en-us/python/api/semantic-link-sempy/sempy.fabric?view=semantic-link-python#sempy-fabric-list-workspaces

# %%
fabric.list_workspaces()
# Out:
# StatementMeta(, cd358454-212c-46f2-a9d3-add66d5e5e7f, 23, Finished, Available, Finished)
#                                       Id  Is Read Only  \
# 0   b1a2b837-44bd-4736-a046-1aef289ba278         False
# 1   f1051dce-0655-47ee-b6f4-0a32e1a5015c         False
# 2   5616d22f-a30d-42d9-a90c-c9c8a637dae0         False
# 3   a2f0fa5a-ad67-4efd-8339-5e18bb653fff         False
# 4   87dc4db6-f916-44ac-88ba-99b2aeca175a         False
# 5   5428b506-e215-4d54-be81-56f7061f68d9         False
# 6   420824e4-1471-4814-858c-cae2cccdc788         False
# 7   ebaa772c-9712-4986-b82d-5c5f4d6d43e6         False
# 8   1f43854a-ebd1-4482-b229-5aa6389d4e1f         False
# 9   91ee8455-1d04-49d3-b7ba-6e5b09c5386e         False
# 10  65135096-a00c-4b1f-a3c7-842e000f4baa         False
# 11  346e4de6-c996-4f59-87ac-7679bfd25b63         False
# 12  e003bf59-ad8b-42ce-bddc-cb7ac5121e61         False
# 13  9aca59b3-11ec-4e2d-9685-4be4e0eb03a7         False
# 14  71a34ad8-49c2-4734-8e16-0e0f68df76c5         False
# 15  a73ecd6b-de2a-4765-a24b-a5d3ec34869a         False
# 16  0f102b14-0309-4241-ba39-c2bef6d33126         False
# 17  45ddc9e8-715c-4767-9bd2-bfc96a3090c8         False
# 18  5e950ed4-941b-4655-8e42-3c02f4c43ee1         False
# 19  cc790872-36f9-4372-9da1-4e2adc3fdd47         False
# 20  9e3e56b1-f43d-4dff-b4d4-c5ec3f6a2cdd         False
# 21  41e2f9a9-1e6c-4068-9a7e-8d34a08cbeb6         False
# 22  1d00920a-61ba-4dba-8059-35297797ca54         False
# 23  da034e22-3589-41f0-8de3-2a841dd1bc9d         False
# 24  92046d34-b8a8-4068-9df8-39f9f6c6d11a         False
# 25  119364b0-0f66-49cd-8f29-2b20149e7dd7         False
# 26  098213ba-fc6b-47e2-96a3-df8d70558f1a         False
# 27  ee44673e-506a-4639-b1f2-d0417a3753a4         False
# 28  9259389b-e0b0-4621-a854-ad9c919decff         False
# 29  dc089dcd-28dd-4da6-be5c-8fe49555e459         False
# 30  aa40cc2e-27b9-4fbe-ab2e-0d40c5c078c3         False
# 31  f01f4c29-c125-4fd4-a047-0ca3b89236f6         False
# 32  e63aa746-dfa4-46d3-b2bd-735a677f7f6c         False
# 33  ee56fd3e-4c5c-421d-bc39-d0c206eb1e70         False
# 34  a6b24fb5-546d-47de-96ba-fb5ae439709a         False
# 35  abc9620d-aca2-4fdc-b14d-12af5bc75250         False
# 36  36c07c45-df33-4c19-ac03-472c158bed43         False
# 37  98aa1e70-1791-4502-962b-02c4612c6d7c         False
# 38  c88b3500-a013-408b-b5e1-0c6e9d378fcf         False
# 39  7cb58fa6-fac7-47b2-a23e-95032083cc7f         False
# 40  fea786ed-97d7-4c7e-9d51-3adc3d7baa17         False
# 41  4b16602a-f34e-4ac1-8c0d-017b5faa6a57         False
# 42  a7938de5-5159-4308-832c-c2db188de71b         False
# 43  cc161638-f97d-45e6-b620-969dc453ed7d         False
# 44  2430b24a-37f3-48fc-bb0f-aa4b1dcadf87         False
# 45  770c9a7e-ea74-4125-861a-53229e12f200         False
# 46  cdf0535b-81e3-4add-af1e-5ebcc241599d         False
# 47  8eaa66ef-5222-492e-b1b4-a555f4f8d1df         False
# 48  f92a39ff-f399-48eb-be69-7ced3fcf7f9e         False
# 49  91d0ccbf-17f9-48ed-937f-b5e9564a28ba         False
# 50  fb99ea0b-d2f9-48d1-9e42-9f712b88b324         False
# 51  235283d5-3a20-4e3c-a82b-952eb04cda75         False
# 52  c44d0b5b-2067-473f-a762-275b92469f26         False
# 53  3487f018-aa60-4b34-99f8-3d1eb59cfdeb         False
# 54  d1831e0d-8ac9-4889-ba91-ae1f06a20159         False
# 55  d0a2160f-6043-474a-b8e8-8e85e86b3c1b         False
#
#     Is On Dedicated Capacity                           Capacity Id  \
# 0                       True  fc3a303d-1acc-43d8-84b8-2a0b7a81a6d4
# 1                      False                                   NaN
# 2                       True  2fa02056-ea13-4f98-bce3-f48c9f65e3e6
# 3                      False                                   NaN
# 4                      False                                   NaN
# 5                      False                                   NaN
# 6                      False                                   NaN
# 7                      False                                   NaN
# 8                      False                                   NaN
# 9                       True  2fa02056-ea13-4f98-bce3-f48c9f65e3e6
# 10                      True  2fa02056-ea13-4f98-bce3-f48c9f65e3e6
# 11                     False                                   NaN
# 12                     False                                   NaN
# 13                     False                                   NaN
# 14                      True  fc3a303d-1acc-43d8-84b8-2a0b7a81a6d4
# 15                      True  fc3a303d-1acc-43d8-84b8-2a0b7a81a6d4
# 16                      True  2fa02056-ea13-4f98-bce3-f48c9f65e3e6
# 17                     False                                   NaN
# 18                      True  2fa02056-ea13-4f98-bce3-f48c9f65e3e6
# 19                      True  2fa02056-ea13-4f98-bce3-f48c9f65e3e6
# 20                      True  fc3a303d-1acc-43d8-84b8-2a0b7a81a6d4
# 21                      True  fc3a303d-1acc-43d8-84b8-2a0b7a81a6d4
# 22                      True  fc3a303d-1acc-43d8-84b8-2a0b7a81a6d4
# 23                     False                                   NaN
# 24                      True  2fa02056-ea13-4f98-bce3-f48c9f65e3e6
# 25                      True  2fa02056-ea13-4f98-bce3-f48c9f65e3e6
# 26                      True  fc3a303d-1acc-43d8-84b8-2a0b7a81a6d4
# 27                     False                                   NaN
# 28                     False                                   NaN
# 29                      True  fc3a303d-1acc-43d8-84b8-2a0b7a81a6d4
# 30                     False                                   NaN
# 31                     False                                   NaN
# 32                     False                                   NaN
# 33                     False                                   NaN
# 34                      True  2fa02056-ea13-4f98-bce3-f48c9f65e3e6
# 35                      True  2fa02056-ea13-4f98-bce3-f48c9f65e3e6
# 36                     False                                   NaN
# 37                      True  2fa02056-ea13-4f98-bce3-f48c9f65e3e6
# 38                     False                                   NaN
# 39                      True  2fa02056-ea13-4f98-bce3-f48c9f65e3e6
# 40                      True  2fa02056-ea13-4f98-bce3-f48c9f65e3e6
# 41                      True  2fa02056-ea13-4f98-bce3-f48c9f65e3e6
# 42                      True  2fa02056-ea13-4f98-bce3-f48c9f65e3e6
# 43                      True  fc3a303d-1acc-43d8-84b8-2a0b7a81a6d4
# 44                      True  2fa02056-ea13-4f98-bce3-f48c9f65e3e6
# 45                      True  2fa02056-ea13-4f98-bce3-f48c9f65e3e6
# 46                      True  2fa02056-ea13-4f98-bce3-f48c9f65e3e6
# 47                      True  2fa02056-ea13-4f98-bce3-f48c9f65e3e6
# 48                      True  2fa02056-ea13-4f98-bce3-f48c9f65e3e6
# 49                      True  2fa02056-ea13-4f98-bce3-f48c9f65e3e6
# 50                      True  2fa02056-ea13-4f98-bce3-f48c9f65e3e6
# 51                      True  2fa02056-ea13-4f98-bce3-f48c9f65e3e6
# 52                     False                                   NaN
# 53                     False                                   NaN
# 54                     False                                   NaN
# 55                     False                                   NaN
#
#    Default Dataset Storage Format       Type  \
# 0                           Small  Workspace
# 1                             NaN  Workspace
# 2                           Small  Workspace
# 3                             NaN  Workspace
# 4                             NaN  Workspace
# 5                             NaN  Workspace
# 6                             NaN  Workspace
# 7                             NaN  Workspace
# 8                             NaN  Workspace
# 9                           Small  Workspace
# 10                          Large  Workspace
# 11                            NaN  Workspace
# 12                            NaN  Workspace
# 13                            NaN  Workspace
# 14                          Small  Workspace
# 15                          Small  Workspace
# 16                          Large  Workspace
# 17                            NaN  Workspace
# 18                          Small  Workspace
# 19                          Small  Workspace
# 20                          Small  Workspace
# 21                          Small  Workspace
# 22                          Large  Workspace
# 23                            NaN  Workspace
# 24                          Small  Workspace
# 25                          Small  Workspace
# 26                          Small  Workspace
# 27                            NaN  Workspace
# 28                            NaN  Workspace
# 29                          Large  Workspace
# 30                            NaN  Workspace
# 31                            NaN  Workspace
# 32                            NaN  Workspace
# 33                            NaN  Workspace
# 34                          Small  Workspace
# 35                          Small  Workspace
# 36                            NaN  Workspace
# 37                          Small  Workspace
# 38                            NaN  Workspace
# 39                          Small  Workspace
# 40                          Small  Workspace
# 41                          Small  Workspace
# 42                          Small  Workspace
# 43                          Small  Workspace
# 44                          Small  Workspace
# 45                          Small  Workspace
# 46                          Small  Workspace
# 47                          Small  Workspace
# 48                          Small  Workspace
# 49                          Small  Workspace
# 50                          Small  Workspace
# 51                          Small  Workspace
# 52                            NaN  Workspace
# 53                            NaN  Workspace
# 54                            NaN  Workspace
# 55                            NaN  Workspace
#
#                                    Name
# 0                              BI_VN_QA
# 1                           BI_SALON_QA
# 2                                 BI_VN
# 3                              BI_SALON
# 4                          BI_MKT_LOCAL
# 5                       BI_MKT_LOCAL_QA
# 6                  BI_ETL_MONITORING_QA
# 7                     BI_ETL_MONITORING
# 8                             BI_EDI_QA
# 9                             BI_FOM_QA
# 10                               BI_FOM
# 11                   BI_REGISTRATION_QA
# 12                               BI_CRM
# 13                            BI_CRM_QA
# 14                             BI_VO_QA
# 15                            BI_DPD_QA
# 16                               BI_DPD
# 17                      BI_REGISTRATION
# 18                BI_BSC_Brands Network
# 19                                BI_VO
# 20                       BI_CAR_PARK_QA
# 21                            BI_DPM_QA
# 22                   INS_AFTER_SALES_QA
# 23                       BI_DataINT_POC
# 24                      BI_DPD_Pre-PROD
# 25                    PBI Support_TEST1
# 26                            BI_CEM_QA
# 27                            BI_GMS_QA
# 28                               BI_GMS
# 29                   INS_AFTER_SALES_DS
# 30         CROSS 3_TO Archive or Delete
# 31  Microsoft 365 - Migration PQH KPI's
# 32                    Extranet_Dieteren
# 33            BI_Roadside Assistance_QA
# 34                               BI_CEM
# 35                          BI_CAR_PARK
# 36               BI_Roadside Assistance
# 37                    PBI Support_TEST2
# 38                  BR_SAP_DATAFLOW_MKT
# 39                                BI_AI
# 40                         BI_HR_ETL_DV
# 41                      BI_HR_REPORT_DV
# 42                BI_DPD_Cross_Pre-Prod
# 43                      BI_DPD_Cross_QA
# 44                          BI_HR_SM_DV
# 45                         BI_HR_ETL_QA
# 46                          BI_HR_SM_QA
# 47                      BI_HR_REPORT_QA
# 48                            BI_HR_ETL
# 49                             BI_HR_SM
# 50                         BI_HR_REPORT
# 51                         BI_DPD_Cross
# 52                            BI_NMS_QA
# 53                               BI_NMS
# 54                           BI_DPAY_QA
# 55                              BI_DPAY

# %% [markdown]
# # Listing Semantic Models from a Remote Workspace
#
# This section demonstrates how to list all semantic models available in a specific Power BI workspace using Microsoft Fabric.<br>
# https://learn.microsoft.com/en-us/python/api/semantic-link-sempy/sempy.fabric?view=semantic-link-python#sempy-fabric-list-datasets

# %%
fabric.list_datasets(workspace="YourWorkspaceHere")
# Out:
# StatementMeta(, cd358454-212c-46f2-a9d3-add66d5e5e7f, 24, Finished, Available, Finished)
#                 Dataset Name                            Dataset ID  \
# 0                DS_DPD_SOMD  75d50958-50cb-47b7-bdca-626cfc6228e5
# 1                  DS_DPD_VN  99e4845b-223a-4254-86e4-82e5cb4c7cd1
# 2                  DS_DPD_VO  1b45bcb7-4687-4904-843a-437b48986415
# 3                  DS_DPD_HR  ec00a1ef-b651-419c-b45b-7e98858cd8d8
# 4                 DS_DPD_JDX  2baf3126-658c-4816-8dee-d0fd8b754b85
# 5             DS_DPD_LEXICON  b250dc4a-fbc0-44b1-8296-6d128e452135
# 6                  DS_DPD_PM  a6fcb2ef-be8f-48a4-bda8-45b7b97d03d8
# 7               DS_DPD_EMPTY  fe10f966-da37-46f4-9289-b1637f04236c
# 8                 DS_DPD_MAG  523f45b4-5439-46b8-8499-36acff0c76a5
# 9                 DS_DPD_MEC  8a85f9a5-d45a-40d4-8d8e-b6dc8955b20c
# 10               DS_DPD_STAT  d94b9d9d-2b7f-49bc-99c4-95aa0fcf23ed
# 11      Usage Metrics Report  7b813231-0795-4dd6-9aba-043902280378
# 12     DS_DPD_NC_ACCESSORIES  3a05b479-61bd-46d2-9f9e-2b2dc1bb3d4f
# 13            DS_DPD_QUALITY  e0117d3d-3270-440e-9c5d-aa0465bb47ce
# 14            DS_DPD_VN_PERF  280d0d63-2d79-4756-855e-26c874bfe2df
# 15               DS_DPD_SMAM  194f1e2e-8295-4d39-b024-f159a4a3a095
# 16          DS_DPD_SOMD_TEST  2f23b04f-f054-43e4-8f1b-f2910e665bcd
# 17             DS_DPD_FINPRO  133e7bfe-6447-4228-90e6-759348552c68
# 18                 DS_DPD_LM  85d0ac6a-2aac-4b6b-80bd-044411d51985
# 19              DS_DPD_VDFIN  7c9c698e-1bb4-497b-a505-1eaf92103ca0
# 20                 DS_DPD_VM  93ed6aa1-56e5-4a3c-9a27-07ccad61f9a4
# 21              DS_DPD_BONUS  e51bbcb7-bfd5-41c2-b5f8-3dc8880a97cc
# 22         DS_DPD Monitoring  5b76604c-3b9e-4424-837d-47172b13feca
# 23    DS_DPD_VN_DATAINT_4817  896adf9f-a4b4-4cc0-9c95-9ab890835ac5
# 24    DS_DPD_VN_DATAINT_5195  05a05b90-99ce-428e-9bf7-734e174ab20e
# 25             DS_DPD_VENICE  73c026d7-4cd0-4337-b259-430da956e7f7
# 26            DS_DPD_WELCOME  28610549-ca78-4896-9134-4e3637814e34
# 27           DS_DPD_SOMD 1.2  a7583f7d-af3e-47ac-84fa-9a995e237594
# 28             DS_DPD_VN 1.2  86711721-54e9-4637-a3ae-1ebad49ff224
# 29  DS_DPD_WELCOME_DYNAMIQUE  e83b4fd4-0a30-47bf-843c-c6d3b05dc7b0
# 30                 DS_DPD_CR  b1aa0b5d-e8be-4090-aa49-bc84dfb056b2
#
#      Created Timestamp Last Update
# 0  2021-03-03 13:46:08         NaT
# 1  2024-07-12 10:25:26         NaT
# 2  2020-12-02 08:16:46         NaT
# 3  2021-06-29 09:20:56         NaT
# 4  2021-01-06 12:19:52         NaT
# 5  2020-10-21 11:21:17         NaT
# 6  2021-07-16 08:42:35         NaT
# 7  2021-08-27 11:59:15         NaT
# 8  2021-01-07 12:20:52         NaT
# 9  2021-01-07 12:20:52         NaT
# 10 2021-06-25 13:42:09         NaT
# 11 2019-10-31 17:16:38         NaT
# 12 2023-01-18 09:12:59         NaT
# 13 2020-12-02 08:16:46         NaT
# 14 1699-12-31 00:00:00         NaT
# 15 2021-01-07 12:20:52         NaT
# 16 2021-03-03 13:46:08         NaT
# 17 2020-12-02 08:16:46         NaT
# 18 2023-09-12 08:02:20         NaT
# 19 2020-12-02 08:16:46         NaT
# 20 2024-04-26 11:17:14         NaT
# 21 2021-01-07 12:20:52         NaT
# 22 2022-08-11 10:03:01         NaT
# 23 2021-03-05 15:44:46         NaT
# 24 2021-03-05 15:44:46         NaT
# 25 2024-07-12 10:25:26         NaT
# 26 2024-01-18 11:03:12         NaT
# 27 2021-03-03 13:46:08         NaT
# 28 2024-07-12 10:25:26         NaT
# 29 2024-01-18 11:03:12         NaT
# 30 2025-02-13 14:47:31         NaT

# %% [markdown]
# # Tabular - BPA - Best Practice Analazyer

# %%
fabric.run_model_bpa(dataset="LazyDAX")
# Out:
# StatementMeta(, cd358454-212c-46f2-a9d3-add66d5e5e7f, 25, Finished, Available, Finished)
#     <style>
#         .tab { overflow: hidden; border: 1px solid #ccc; background-color: #f1f1f1; }
#         .tab button { background-color: inherit; float: left; border: none; outline: none; cursor: pointer; padding: 14px 16px; transition: 0.3s; }
#         .tab button:hover { background-color: #ddd; }
#         .tab button.active { background-color: #ccc; }
#         .tabcontent { display: none; padding: 6px 12px; border: 1px solid #ccc; border-top: none; }
#         .tabcontent.active { display: block; }
#         .tooltip { position: relative; display: inline-block; }
#         .tooltip .tooltiptext { visibility: hidden; width: 300px; background-color: #555; color: #fff; text-align: center; border-radius: 6px; padding: 5px; position: absolute; z-index: 1; bottom: 125%; left: 50%; margin-left: -110px; opacity: 0; transition: opacity 0.3s; }
#         .tooltip:hover .tooltiptext { visibility: visible; opacity: 1; }
#     </style>
#     <div class="tab"><button class="tablinks active" onclick="openTab(event, 'tab0')"><b>DAX Expressions</b><br/>⚠️ (14)</button><button class="tablinks " onclick="openTab(event, 'tab1')"><b>Formatting</b><br/>⚠️ (510) + ℹ️ (442) + ❌ (1)</button><button class="tablinks " onclick="openTab(event, 'tab2')"><b>Maintenance</b><br/>ℹ️ (74) + ⚠️ (12)</button><button class="tablinks " onclick="openTab(event, 'tab3')"><b>Performance</b><br/>⚠️ (56)</button></div><div id="tab0" class="tabcontent active"><table border="1"><tr><th>Rule Name</th><th>Object Type</th><th>Object Name</th><th>Severity</th></tr><tr><td class="tooltip" onmouseover="adjustTooltipPosition(event)">Avoid addition or subtraction of constant values to results of divisions<span class="tooltiptext">Adding a constant value may lead to performance degradation.</span></td><td>Measure</td><td>CALCULATE FILTER</td><td style="text-align: center;">⚠️</td></tr><tr><td class="tooltip" onmouseover="adjustTooltipPosition(event)"><a href="https://www.elegantbi.com/post/top10bestpractices">Avoid using the IFERROR function</a><span class="tooltiptext">Avoid using the IFERROR function as it may cause performance degradation. If you are concerned about a divide-by-zero error, use the DIVIDE function as it naturally resolves such errors as blank (or you can customize what should be shown in case of such an error).</span></td><td>Measure</td><td>IFERROR</td><td style="text-align: center;">⚠️</td></tr><tr><td class="tooltip" onmouseover="adjustTooltipPosition(event)"><a href="https://docs.microsoft.com/power-bi/guidance/dax-avoid-avoid-filter-as-filter-argument  Reference: https://www.sqlbi.com/articles/using-keepfilters-in-dax">Filter column values with proper syntax</a><span class="tooltiptext">Instead of using this pattern FILTER('Table','Table'[Column]="Value") for the filter parameters of a CALCULATE or CALCULATETABLE function, use one of the options below. As far as whether to use the KEEPFILTERS function, see the second reference link below.
# Option 1: KEEPFILTERS('Table'[Column]="Value")
# Option 2: 'Table'[Column]="Value"</span></td><td>Measure</td><td>Amount Fruit</td><td style="text-align: center;">⚠️</td></tr><tr><td class="tooltip" onmouseover="adjustTooltipPosition(event)"><a href="https://docs.microsoft.com/power-bi/guidance/dax-avoid-avoid-filter-as-filter-argument  Reference: https://www.sqlbi.com/articles/using-keepfilters-in-dax">Filter column values with proper syntax</a><span class="tooltiptext">Instead of using this pattern FILTER('Table','Table'[Column]="Value") for the filter parameters of a CALCULATE or CALCULATETABLE function, use one of the options below. As far as whether to use the KEEPFILTERS function, see the second reference link below.
# Option 1: KEEPFILTERS('Table'[Column]="Value")
# Option 2: 'Table'[Column]="Value"</span></td><td>Measure</td><td>Amount Fruit (All Product)</td><td style="text-align: center;">⚠️</td></tr><tr><td class="tooltip" onmouseover="adjustTooltipPosition(event)"><a href="https://docs.microsoft.com/power-bi/guidance/dax-avoid-avoid-filter-as-filter-argument  Reference: https://www.sqlbi.com/articles/using-keepfilters-in-dax">Filter column values with proper syntax</a><span class="tooltiptext">Instead of using this pattern FILTER('Table','Table'[Column]="Value") for the filter parameters of a CALCULATE or CALCULATETABLE function, use one of the options below. As far as whether to use the KEEPFILTERS function, see the second reference link below.
# Option 1: KEEPFILTERS('Table'[Column]="Value")
# Option 2: 'Table'[Column]="Value"</span></td><td>Measure</td><td>Amount Y-1 Filter 2</td><td style="text-align: center;">⚠️</td></tr><tr><td class="tooltip" onmouseover="adjustTooltipPosition(event)"><a href="https://docs.microsoft.com/power-bi/guidance/dax-avoid-avoid-filter-as-filter-argument  Reference: https://www.sqlbi.com/articles/using-keepfilters-in-dax">Filter column values with proper syntax</a><span class="tooltiptext">Instead of using this pattern FILTER('Table','Table'[Column]="Value") for the filter parameters of a CALCULATE or CALCULATETABLE function, use one of the options below. As far as whether to use the KEEPFILTERS function, see the second reference link below.
# Option 1: KEEPFILTERS('Table'[Column]="Value")
# Option 2: 'Table'[Column]="Value"</span></td><td>Measure</td><td>CALCULATETABLE</td><td style="text-align: center;">⚠️</td></tr><tr><td class="tooltip" onmouseover="adjustTooltipPosition(event)"><a href="https://docs.microsoft.com/power-bi/guidance/dax-avoid-avoid-filter-as-filter-argument  Reference: https://www.sqlbi.com/articles/using-keepfilters-in-dax">Filter column values with proper syntax</a><span class="tooltiptext">Instead of using this pattern FILTER('Table','Table'[Column]="Value") for the filter parameters of a CALCULATE or CALCULATETABLE function, use one of the options below. As far as whether to use the KEEPFILTERS function, see the second reference link below.
# Option 1: KEEPFILTERS('Table'[Column]="Value")
# Option 2: 'Table'[Column]="Value"</span></td><td>Measure</td><td>COALESCE</td><td style="text-align: center;">⚠️</td></tr><tr><td class="tooltip" onmouseover="adjustTooltipPosition(event)"><a href="https://docs.microsoft.com/power-bi/guidance/dax-avoid-avoid-filter-as-filter-argument  Reference: https://www.sqlbi.com/articles/using-keepfilters-in-dax">Filter column values with proper syntax</a><span class="tooltiptext">Instead of using this pattern FILTER('Table','Table'[Column]="Value") for the filter parameters of a CALCULATE or CALCULATETABLE function, use one of the options below. As far as whether to use the KEEPFILTERS function, see the second reference link below.
# Option 1: KEEPFILTERS('Table'[Column]="Value")
# Option 2: 'Table'[Column]="Value"</span></td><td>Measure</td><td>Nb VEGETABLE _</td><td style="text-align: center;">⚠️</td></tr><tr><td class="tooltip" onmouseover="adjustTooltipPosition(event)"><a href="https://docs.microsoft.com/power-bi/guidance/dax-avoid-avoid-filter-as-filter-argument  Reference: https://www.sqlbi.com/articles/using-keepfilters-in-dax">Filter column values with proper syntax</a><span class="tooltiptext">Instead of using this pattern FILTER('Table','Table'[Column]="Value") for the filter parameters of a CALCULATE or CALCULATETABLE function, use one of the options below. As far as whether to use the KEEPFILTERS function, see the second reference link below.
# Option 1: KEEPFILTERS('Table'[Column]="Value")
# Option 2: 'Table'[Column]="Value"</span></td><td>Measure</td><td>Nb VeGeTaBlE __</td><td style="text-align: center;">⚠️</td></tr><tr><td class="tooltip" onmouseover="adjustTooltipPosition(event)"><a href="https://docs.microsoft.com/power-bi/guidance/dax-avoid-avoid-filter-as-filter-argument  Reference: https://www.sqlbi.com/articles/using-keepfilters-in-dax">Filter column values with proper syntax</a><span class="tooltiptext">Instead of using this pattern FILTER('Table','Table'[Column]="Value") for the filter parameters of a CALCULATE or CALCULATETABLE function, use one of the options belo

# %% [markdown]
# ## Checking Refresh Status of a Semantic Model
#
# This section demonstrates how to retrieve refresh information for a Power BI Semantic Model in Microsoft Fabric.

# %%
import sempy.fabric as fabric
fabric.list_refresh_requests(dataset="LazyDAX")
# Out:
# StatementMeta(, cd358454-212c-46f2-a9d3-add66d5e5e7f, 26, Finished, Available, Finished)
#            Id                            Request Id  \
# 0  1060164116  24ae20c8-9d2e-b8b6-6479-7d6e9d86eec6
# 1  1060164010  6d659323-b68c-6886-4eb8-4389ac8a1cad
#
#                         Start Time                         End Time  \
# 0 2025-02-28 10:12:29.053000+00:00 2025-02-28 10:12:36.007000+00:00
# 1 2025-02-28 10:12:01.877000+00:00 2025-02-28 10:12:09.457000+00:00
#
#   Refresh Type Service Exception Json     Status Extended Status  \
# 0     OnDemand                    NaN  Completed             NaN
# 1     OnDemand                    NaN  Completed             NaN
#
#                                     Refresh Attempts
# 0  [{'attemptId': 1, 'startTime': '2025-02-28T10:...
# 1  [{'attemptId': 1, 'startTime': '2025-02-28T10:...
